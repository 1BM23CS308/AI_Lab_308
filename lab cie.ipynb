# %% [markdown]
# <a href="https://colab.research.google.com/github/1BM23CS308/AI_Lab_308/blob/main/lab%20cie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

def alpha_beta(depth, node_index, is_maximizing, values, alpha, beta, max_depth):
    indent = "   " * depth
    if depth == max_depth:
        print(f"{indent}Leaf node[{node_index}] = {values[node_index]}")
        return values[node_index]

    if is_maximizing:
        best = -math.inf
        print(f"{indent}MAX node (α={alpha}, β={beta})")
        for i in range(2):
            val = alpha_beta(depth + 1, node_index * 2 + i, False, values, alpha, beta, max_depth)
            best = max(best, val)
            alpha = max(alpha, best)
            print(f"{indent}   MAX updating α={alpha}")
            if beta <= alpha:
                print(f"{indent}   β cut-off (β={beta}, α={alpha}) ")
                break
        return best
    else:
        best = math.inf
        print(f"{indent}MIN node (α={alpha}, β={beta})")
        for i in range(2):
            val = alpha_beta(depth + 1, node_index * 2 + i, True, values, alpha, beta, max_depth)
            best = min(best, val)
            beta = min(beta, best)
            print(f"{indent}   MIN updating β={beta}")
            if beta <= alpha:
                print(f"{indent}   α cut-off (β={beta}, α={alpha}) ")
                break
        return best


values = [8,7,9,2,11,8,10,3,12,4,6,9,6,14,12,20,10,2]
max_depth = int(math.log2(len(values)))

print("Leaf Nodes:", values)
result = alpha_beta(0, 0, True, values, -math.inf, math.inf, max_depth)
print("\nOptimal value:", result)
# Out:
# Leaf Nodes: [8, 7, 9, 2, 11, 8, 10, 3, 12, 4, 6, 9, 6, 14, 12, 20, 10, 2]
# MAX node (α=-inf, β=inf)
#    MIN node (α=-inf, β=inf)
#       MAX node (α=-inf, β=inf)
#          MIN node (α=-inf, β=inf)
#             Leaf node[0] = 8
#             MIN updating β=8
#             Leaf node[1] = 7
#             MIN updating β=7
#          MAX updating α=7
#          MIN node (α=7, β=inf)
#             Leaf node[2] = 9
#             MIN updating β=9
#             Leaf node[3] = 2
#             MIN updating β=2
#             α cut-off (β=2, α=7)
#          MAX updating α=7
#       MIN updating β=7
#       MAX node (α=-inf, β=7)
#          MIN node (α=-inf, β=7)
#             Leaf node[4] = 11
#             MIN updating β=7
#             Leaf node[5] = 8
#             MIN updating β=7
#          MAX updating α=8
#          β cut-off (β=7, α=8)
#       MIN updating β=7
#    MAX updating α=7
#    MIN node (α=7, β=inf)
#       MAX node (α=7, β=inf)
#          MIN node (α=7, β=inf)
#             Leaf node[8] = 12
#             MIN updating β=12
#             Leaf node[9] = 4
#             MIN updating β=4
#             α cut-off (β=4, α=7)
#          MAX updating α=7
#          MIN node (α=7, β=inf)
#             Leaf node[10] = 6
#             MIN updating β=6
#             α cut-off (β=6, α=7)
#          MAX updating α=7
#       MIN updating β=6
#       α cut-off (β=6, α=7)
#    MAX updating α=7
#
# Optimal value: 7
